# %% [markdown]
# # 🚀 OpenEnv Hackathon: Incident Response Multi-Agent System Training
#
# Welcome to the training notebook for our autonomous incident response agent! This notebook trains a reinforcement learning agent to diagnose and resolve production incidents using **OpenEnv**.
#
# ## 🌟 Key Features
# - **Multi-Agent Framework**: Uses Responder & Challenger agents.
# - **Curriculum Learning**: Progresses from easy to hard incidents.
# - **Hugging Face Integration**: Uses Qwen2.5/Llama-3.2 for reasoning.
#
# Run the cells below to setup the environment and begin training.

# %%
# !pip install openenv-py huggingface_hub transformers accelerate

# %%
import os
from huggingface_hub import login

# Please insert your Hugging Face API token below
HF_TOKEN = "hf_your_token_here"  # @param {type:"string"}
os.environ["HF_TOKEN"] = HF_TOKEN
login(token=HF_TOKEN)

# %% [markdown]
# ## 🏋️‍♂️ Run the Training Script
# We simulate the incident scenarios dynamically via `scenarios/scenario_generator.py` and train the agent through our custom RL loop.

# %%
# !python test_rl_loop.py
